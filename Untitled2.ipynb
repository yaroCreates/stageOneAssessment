# %%
A = [1,2,3,4,5,6]
B = [13,21,34]

# %%
print(A)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(A+B)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
A.append(B)

# %%
print(A.append(B))
# Out:
# None

# %%
print(A.extend(B))
# Out:
# None

# %%
import numpy as np

# %%
p = np.array([[1,0,0],[0,1,0],[0,0,1]])

# %%
print(p)
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]

# %%
q = np.eye(3)
print(q)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
m = np.identity(3)
print(m)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
import pandas as pd

# %%
# Loading csv file 
csv_file = pd.read_csv("C:/Users/Kurzin Kazan/Desktop/DS/Sample File.csv")
print('File read successfully')
# Out:
# File read successfully

# %%
csv_file.head()
# Out:
#    Unnamed: 0               record_id  utility_id_ferc1  report_year  \
# 0           0   f1_fuel_1994_12_1_0_7                 1         1994
# 1           1  f1_fuel_1994_12_1_0_10                 1         1994
# 2           2   f1_fuel_1994_12_2_0_1                 2         1994
# 3           3   f1_fuel_1994_12_2_0_7                 2         1994
# 4           4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# ...

# %%
csv_file.isnull().sum()
# Out:
# Unnamed: 0                        0
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
csv_file.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
csv_file[['fuel_unit']] = csv_file[['fuel_unit']].fillna(value='mcf')

# %%
csv_file.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
csv_file.groupby('fuel_type_code_pudl')['fuel_type_code_pudl'].count()
# Out:
# fuel_type_code_pudl
# coal        8547
# gas        11486
# nuclear      818
# oil         8064
# other        167
# waste        441
# Name: fuel_type_code_pudl, dtype: int64

# %%
csv_file.groupby('fuel_type_code_pudl').first()
# Out:
#                      Unnamed: 0               record_id  utility_id_ferc1  \
# fuel_type_code_pudl
# coal                          0   f1_fuel_1994_12_1_0_7                 1
# gas                           4  f1_fuel_1994_12_2_0_10                 2
# nuclear                       6   f1_fuel_1994_12_2_1_1                 2
# oil                          14   f1_fuel_1994_12_6_0_2                 6
# other                        84  f1_fuel_1994_12_11_0_6                11
# waste                        49   f1_fuel_1994_12_9_0_3                 9
#
#                      report_year  plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                        1994          rockport       ton        5377489.0
# gas                         1994         chickasaw       mcf          40533.0
# nuclear                     1994  joseph m. farley       kgU           2260.0
# oil                         1994      clinch river       bbl           6510.0
# ...

# %%
csv_file.describe()
# Out:
#          Unnamed: 0  utility_id_ferc1   report_year  fuel_qty_burned  \
# count  29523.000000      29523.000000  29523.000000     2.952300e+04
# mean   14761.000000        118.601836   2005.806050     2.622119e+06
# std     8522.700335         74.178353      7.025483     9.118004e+06
# min        0.000000          1.000000   1994.000000     1.000000e+00
# 25%     7380.500000         55.000000   2000.000000     1.381700e+04
# 50%    14761.000000        122.000000   2006.000000     2.533220e+05
# 75%    22141.500000        176.000000   2012.000000     1.424034e+06
# max    29522.000000        514.000000   2018.000000     5.558942e+08
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# count         29523.000000               29523.000000
# mean              8.492111                 208.649031
# std              10.600220                2854.490090
# min               0.000001                -276.080000
# 25%               1.024000                   5.207000
# ...

# %%
csv_file.groupby('fuel_mmbtu_per_unit').first()
# Out:
#                      Unnamed: 0                 record_id  utility_id_ferc1  \
# fuel_mmbtu_per_unit
# 0.000001                   7596   f1_fuel_2000_12_155_0_1               155
# 0.000005                   6918    f1_fuel_2000_12_39_2_7                39
# 0.000006                    211    f1_fuel_1994_12_38_0_1                38
# 0.000007                   5345   f1_fuel_1998_12_146_1_1               146
# 0.000009                  24179  f1_fuel_2013_12_193_0_13               193
# ...                         ...                       ...               ...
# 124.855946                 1112   f1_fuel_1994_12_76_0_10                76
# 124.860000                 1046   f1_fuel_1994_12_32_4_13                32
# 124.879004                 3671   f1_fuel_1997_12_46_1_10                46
# 125.120000                 2497    f1_fuel_1996_12_32_5_1                32
# 341.260000                 4782    f1_fuel_1998_12_63_0_2                63
#
# ...

# %%
csv_file.groupby('fuel_cost_per_unit_delivered').first()
# Out:
#                               Unnamed: 0                 record_id  \
# fuel_cost_per_unit_delivered
# -874.937                           17525   f1_fuel_2008_12_177_1_1
# -488.054                           16634   f1_fuel_2007_12_177_2_4
# -313.410                           12975   f1_fuel_2004_12_210_1_6
# -174.670                            7730  f1_fuel_2000_12_194_2_15
# -170.187                           26352     f1_fuel_2015_12_6_1_2
# ...                                  ...                       ...
#  1942979.000                        3566    f1_fuel_1997_12_9_0_14
#  2114508.000                        3245    f1_fuel_1996_12_9_0_14
#  2255688.000                        3565    f1_fuel_1997_12_9_0_11
#  7793482.000                        3244     f1_fuel_1996_12_9_0_8
#  7964521.000                        3564     f1_fuel_1997_12_9_0_8
#
#                               utility_id_ferc1  report_year  \
# fuel_cost_per_unit_delivered
# ...

# %%
csv_file.groupby('fuel_cost_per_unit_burned').first()
# Out:
#                            Unnamed: 0                 record_id  \
# fuel_cost_per_unit_burned
# -276.080                         7733   f1_fuel_2000_12_194_3_3
# -174.670                         7736   f1_fuel_2000_12_194_3_6
# -123.310                         7730  f1_fuel_2000_12_194_2_15
# -119.040                        11242   f1_fuel_2003_12_281_1_4
# -85.760                          2123   f1_fuel_1995_12_194_5_9
# ...                               ...                       ...
#  65137.588                      22991    f1_fuel_2012_12_7_7_13
#  69785.215                      21483    f1_fuel_2011_12_7_7_13
#  80459.000                      24577   f1_fuel_2014_12_177_2_7
#  83538.000                      20719   f1_fuel_2011_12_132_1_2
#  139358.000                     25127   f1_fuel_2014_12_147_0_2
#
#                            utility_id_ferc1  report_year     plant_name_ferc1  \
# fuel_cost_per_unit_burned
# ...

# %%
csv_file.groupby('fuel_cost_per_unit_delivered').first()
# Out:
#                               Unnamed: 0                 record_id  \
# fuel_cost_per_unit_delivered
# -874.937                           17525   f1_fuel_2008_12_177_1_1
# -488.054                           16634   f1_fuel_2007_12_177_2_4
# -313.410                           12975   f1_fuel_2004_12_210_1_6
# -174.670                            7730  f1_fuel_2000_12_194_2_15
# -170.187                           26352     f1_fuel_2015_12_6_1_2
# ...                                  ...                       ...
#  1942979.000                        3566    f1_fuel_1997_12_9_0_14
#  2114508.000                        3245    f1_fuel_1996_12_9_0_14
#  2255688.000                        3565    f1_fuel_1997_12_9_0_11
#  7793482.000                        3244     f1_fuel_1996_12_9_0_8
#  7964521.000                        3564     f1_fuel_1997_12_9_0_8
#
#                               utility_id_ferc1  report_year  \
# fuel_cost_per_unit_delivered
# ...

# %%
#Calculating Skewness
csv_file.skew()
# Out:
# Unnamed: 0                        0.000000
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
#Calculating Kurtosis
csv_file.kurt()
# Out:
# Unnamed: 0                         -1.200000
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64
